# %% [markdown]
# # Data Preprocessing
#
# ## Objective
#
# The objective of this notebook is to clean the raw NCI-ALMANAC dataset before feature engineering.
#
# The first preprocessing step is to remove single-drug experiments because this project focuses on drug combinations.

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/raw/ComboDrugGrowth_Nov2017.csv")
# Out:
# /tmp/ipykernel_2027693/2493506421.py:1: DtypeWarning: Columns (0: PLATE) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/raw/ComboDrugGrowth_Nov2017.csv")
